# %%
import pandas as pd
import numpy as np
df3=pd.read_excel(r'F:\Output Messenger\Received Files\16-23Jan.xlsx')

# %%
Date=input('Please Enter Date (YYYY-MM-DD):')
df2=df3[df3['Date']==Date]
# Out:
# Please Enter Date (YYYY-MM-DD):2020-01-20

# %%
df = pd.DataFrame({"lon1" : df2['Long1'],
                   "lat1" : df2['Lat1'],
                   "lon2" : df2['Long2'],
                   "lat2" : df2['Lat2']})

# %%
lon1, lat1 = m(df.lon1.values, df.lat1.values)
#lon2, lat2 = m(df.lon2.values, df.lat2.values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-4d5eccd44fed> in <module>
# ----> 1 lon1, lat1 = m(df.lon1.values, df.lat1.values)
#       2 #lon2, lat2 = m(df.lon2.values, df.lat2.values)
#
# NameError: name 'm' is not defined

# %%
pts = np.c_[lon1, lat1, lon2, lat2].reshape(len(lon1), 2, 2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-4386a96f6517> in <module>
# ----> 1 pts = np.c_[lon1, lat1, lon2, lat2].reshape(len(lon1), 2, 2)
#
# NameError: name 'lon1' is not defined

# %%
import os
os.environ['PROJ_LIB'] = r'C:\Users\Milad\Anaconda3\envs\py35\Library\share'

import numpy as np; np.random.seed(42)
import pandas as pd
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
# %matplotlib notebook
from matplotlib.collections import LineCollection


m = Basemap(llcrnrlon=40.185758,llcrnrlat=23.325423,urcrnrlon=62.154774,urcrnrlat=42.615750,
             resolution='i', lat_0 = 32.437567, lon_0 = 53.411987)
plt.figure(figsize=(12,6))
#m.drawcoastlines(linewidth=0.1, color='gray')
m.drawcountries(zorder=0, color='gray')
m.drawrivers(zorder=0, color='blue')
m.drawstates(color='gray')
#m.etopo()

#m.arcgisimage(xpixels=10000, dpi=96, pverbose=True)

lon1, lat1 = m(df.lon1.values, df.lat1.values)
lon2, lat2 = m(df.lon2.values, df.lat2.values)

pts = np.c_[lon1, lat1, lon2, lat2].reshape(len(lon1), 2, 2)
plt.gca().add_collection(LineCollection(pts, color= 'red', label="Links"))



m.plot(lon1, lat1, marker="o", ls="", label="Nend")
m.plot(lon2, lat2, marker="o", ls="", label="Fend")

plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1199.9999632529172">

# %%
import gmplot 
  
# from_geocode method return the 
# latitude and longitude of given location . 
gmap2 = gmplot.GoogleMapPlotter( 32.497901, 54.255800, 13) 
  
gmap2.draw( "C:\\Users\\milad\\Desktop\\map12.html" )

# %%
import gmplot 
  
latitude_list = [ 30.3358376, 30.307977, 30.3216419 ] 
longitude_list = [ 77.8701919, 78.048457, 78.0413095 ] 
  
gmap3 = gmplot.GoogleMapPlotter(32.497901, 54.255800, 13) 
  
# scatter method of map object  
# scatter points on the google map 
gmap3.scatter( latitude_list, longitude_list, '# FF0000', 
                              size = 40, marker = False ) 
  
# Plot method Draw a line in 
# between given coordinates 
gmap3.plot(latitude_list, longitude_list,  
           'cornflowerblue', edge_width = 2.5) 
  
gmap3.draw( "C:\\Users\\milad\\Desktop\\map13.html" )
